# %%
import pandas as pd

# %%
sdg = pd.read_csv(r'C:\Users\EDS\OneDrive - Extreme Digital Solutions\Documentos\TADS020\Big Data\Big-Data\Atividade 4\unsdg_2002_2021.csv', sep =',')

# %%
sdg.head(1-2)
# Out:
#       dt_year     dt_date      country                     region  \
# 0        2002  2002-01-01  Afghanistan  Central and Southern Asia
# 1        2003  2003-01-01  Afghanistan  Central and Southern Asia
# 2        2004  2004-01-01  Afghanistan  Central and Southern Asia
# 3        2005  2005-01-01  Afghanistan  Central and Southern Asia
# 4        2006  2006-01-01  Afghanistan  Central and Southern Asia
# ...       ...         ...          ...                        ...
# 5170     2016  2016-01-01     Zimbabwe         Sub-Saharan Africa
# 5171     2017  2017-01-01     Zimbabwe         Sub-Saharan Africa
# 5172     2018  2018-01-01     Zimbabwe         Sub-Saharan Africa
# 5173     2019  2019-01-01     Zimbabwe         Sub-Saharan Africa
# 5174     2020  2020-01-01     Zimbabwe         Sub-Saharan Africa
#
#       level_of_development  greenhousegas_emissione_mtco2equivalent  \
# 0          Least Developed                                      NaN
# ...
